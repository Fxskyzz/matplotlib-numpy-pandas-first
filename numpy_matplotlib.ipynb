# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 准备数据
x = np.linspace(-10, 10, 1000)
y = np.sin(x)

# 创建画布
plt.figure(figsize=(10, 4))

# 绘制函数
plt.plot(x, y)

# 添加网格显示
plt.grid()

# 显示图像
plt.show()
