# %%
import matplotlib.pyplot as plt

# %%
# %time x = list(range(10))
# %time y = list(range(10, 20))
# Out:
# CPU times: user 2 µs, sys: 2 µs, total: 4 µs
# Wall time: 5.96 µs
# CPU times: user 2 µs, sys: 2 µs, total: 4 µs
# Wall time: 5.01 µs

# %%
# 创建画布
plt.figure(figsize=(10, 4))
plt.plot(x, y)
# %time plt.show()
# Out:
# CPU times: user 118 ms, sys: 138 ms, total: 256 ms
# Wall time: 186 ms

# %%
import matplotlib.pyplot as plt
import random

# %%
x = range(60)
y = [random.uniform(15, 18) for i in x]
y1 = [random.uniform(25, 35) for i in x]

# %%
# 创建画布
plt.figure(figsize=(10, 4))
plt.plot(x, y, label="gz")
plt.plot(x, y1, label="sz")

# 添加刻度值
x_ticks = ["11.{}min".format(i) for i in x]
y_ticks = range(40)


plt.xticks(x[::5], x_ticks[::5])
plt.yticks(y_ticks[::5])

# 添加网格
plt.grid(True, linestyle='--', alpha=0.5)

# 添加描述信息
plt.xlabel("time", fontsize=14)
plt.ylabel("temp", fontsize=14)
plt.title("this is only a title", fontsize=20)

plt.savefig("test.png")

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x = range(60)
y_shanghai = [random.uniform(15, 18) for i in x]
y_beijing = [random.uniform(1, 5) for i in x]

# %%
# 创建画布
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4), dpi=80)

# 绘制图像
axes[0].plot(x, y_shanghai, label="shanghai")
axes[1].plot(x, y_beijing, label="beijing", color="r", linestyle="--")

# 添加图例
axes[0].legend(loc="best")
axes[1].legend(loc="best")
plt.show()
